# %% [markdown]
# # Edge Detection
#
# Identifying sharp change in the intensity in adjacent pixels
# ![image info](./notebook/one.jpg)

# %% [markdown]
# values of black and white
# ![image info](./notebook/two.jpg)
# 0 correspond to black, and 255 to white

# %% [markdown]
# Gradient: Measuare of change in brigtness over adjacent pixels
# ![image info](./notebook/three.jpg)

# %% [markdown]
# Edge: rapid change in brithnees

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image=cv2.imread("test_image.jpg")
lane_image=np.copy(image)
gray=cv2.cvtColor(lane_image,cv2.COLOR_RGB2GRAY)
plt.imshow(lane_image)

# %%
plt.imshow(gray)
